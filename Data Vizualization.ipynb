# %%
# seaborn, matplotlib.pyplot, plotly, bokeh, d3, dash
# aws elastic beanstalk
# seaborn is built on top of matplotlib.pyplot. it provides high level coding instructions to draw more informational statistial data

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
fifa_file = pd.read_csv(r"C:\Users\lenovo\Documents\Uma\data\data fr viz\fifa.csv", index_col = "Date", parse_dates = True)

# %%
fifa_file = fifa_file.set_index("Date")

# %%
fifa_file
# Out:
#              ARG  BRA   ESP   FRA  GER   ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ...          ...  ...   ...   ...  ...   ...
# 2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 6 columns]

# %% [markdown]
# # Line Chart

# %%
sns.lineplot(data = fifa_file)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.figure(figsize = (20, 10))
sns.lineplot(data = fifa_file)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
s_data = pd.read_csv(r"C:\Users\lenovo\Documents\Uma\data\data fr viz\spotify.csv", index_col = "Date", parse_dates = True)

# %%
s_data
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# ...

# %%
s_data.isna().sum()
# Out:
# Shape of You                 0
# Despacito                    7
# Something Just Like This    47
# HUMBLE.                     84
# Unforgettable               91
# dtype: int64

# %%
sns.lineplot(data = s_data)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.figure(figsize = (20,10))
sns.lineplot(data = s_data)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.figure(figsize = (16,6))
plt.title("Popularity for Despacito and unforgettable between 2017 and 2018")
sns.lineplot(data = s_data['Despacito'], label = 'Desp')
sns.lineplot(data = s_data['Unforgettable'], label = 'Unfor')
plt.xlabel('From the release to peak popularity 2017-18')
# Out:
# Text(0.5, 0, 'From the release to peak popularity 2017-18')

# %%
plt.figure(figsize = (16,6))
plt.title("Popularity for Despacito and unforgettable between 2017 and 2018")
sns.lineplot(data = s_data['Despacito'], label = 'Desp')
sns.lineplot(data = s_data['Shape of You'], label = 'SoY')
plt.xlabel('From the release to peak popularity 2017-18')
# Out:
# Text(0.5, 0, 'From the release to peak popularity 2017-18')

# %%
# get the data- validate
# get additional info

# %% [markdown]
# # Bar Plot

# %%
f_data = pd.read_csv(r"C:\Users\lenovo\Documents\Uma\data\data fr viz\flight_delays.csv", index_col = 'Month')

# %%
f_data.head()
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#              HA         MQ         NK         OO        UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894  6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895  7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693  4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796  4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162  6.827695  0.681605
#
#              VX        WN
# Month
# 1      1.420702  3.389466
# 2      7.784410  3.501363
# 3      5.348207  3.263341
# ...

# %%
plt.figure(figsize = (16,6))
plt.title("Average arrival delay for Inceptez Airlines WN, by month")
sns.barplot(x = f_data.index, y = f_data['WN'])
plt.ylabel("Arrival delay in mins")
plt.xlabel("Month as integers")
# Out:
# Text(0.5, 0, 'Month')

# %%
plt.figure(figsize = (16,6))
plt.title("Average arrival delay for Inceptez Airlines NK, by month")
sns.barplot(x = f_data.index, y = f_data['NK'])
plt.ylabel("Arrival delay in mins")
plt.xlabel("Month as integers")
# Out:
# Text(0.5, 0, 'Month as integers')

# %% [markdown]
# # Heat map

# %%
#tells magnitude of each location monthwise as colors
plt.figure(figsize = (8,8))
plt.title("Average arrival delay for Inceptez Airlines WN, by month")
sns.heatmap(data = f_data,annot = True)
plt.ylabel("Arrival delay in mins")
plt.xlabel("Month as integers")
# Out:
# Text(0.5, 51.0, 'Month as integers')

# %%
#tells magnitude 
plt.figure(figsize = (8,8))
plt.title("Average arrival delay for Inceptez Airlines WN, by month")
sns.heatmap(data = f_data)
plt.ylabel("Arrival delay in mins")
plt.xlabel("Month as integers")
# Out:
# Text(0.5, 51.0, 'Month as integers')

# %%
#tells magnitude 
plt.figure(figsize = (8,8))
plt.title("Average arrival delay for Inceptez Airlines WN, by month")
sns.heatmap(data = f_data,annot = True, vmin = -10, vmax = 40)
plt.ylabel("Arrival delay in mins")
plt.xlabel("Month as integers")
# Out:
# Text(0.5, 51.0, 'Month as integers')

# %%
#tells magnitude 
plt.figure(figsize = (8,8))
plt.title("Average arrival delay for Inceptez Airlines WN, by month")
sns.heatmap(data = f_data, cmap = 'YlGnBu')
plt.ylabel("Arrival delay in mins")
plt.xlabel("Month as integers")
# Out:
# Text(0.5, 51.0, 'Month as integers')

# %%
#tells magnitude 
plt.figure(figsize = (10,10))
plt.title("Average arrival delay for Inceptez Airlines WN, by month")
sns.heatmap(data = f_data,annot = True, vmin = -1, vmax = 1)
plt.ylabel("Arrival delay in mins")
plt.xlabel("Month as integers")
# Out:
# Text(0.5, 69.0, 'Month as integers')

# %%
f_data.corr()
# Out:
#           AA        AS        B6        DL        EV        F9        HA  \
# AA  1.000000  0.334980  0.429854  0.805229  0.896523  0.903986  0.220065
# AS  0.334980  1.000000  0.340359  0.394359  0.356608  0.336791  0.684979
# B6  0.429854  0.340359  1.000000  0.643313  0.342627  0.510718  0.467905
# DL  0.805229  0.394359  0.643313  1.000000  0.796951  0.783265  0.262251
# EV  0.896523  0.356608  0.342627  0.796951  1.000000  0.828515  0.099369
# F9  0.903986  0.336791  0.510718  0.783265  0.828515  1.000000  0.273878
# HA  0.220065  0.684979  0.467905  0.262251  0.099369  0.273878  1.000000
# MQ  0.842701  0.283977  0.529724  0.598765  0.721468  0.912984  0.436015
# NK  0.573716  0.480863  0.032038  0.625277  0.784026  0.414064  0.176485
# OO  0.620477  0.350657  0.591115  0.569073  0.692697  0.582509  0.056941
# UA  0.809874  0.457414  0.233021  0.797339  0.911499  0.671986  0.066821
# US  0.823713  0.489025  0.788345  0.821757  0.669736  0.878874  0.586160
# ...

# %%
plt.figure(figsize = (10,10))
plt.title("Average arrival delay for Inceptez Airlines WN, by month")
sns.heatmap(data = f_data.corr(),annot = True, vmin = -1, vmax = 1)
plt.ylabel("Arrival delay in mins")
plt.xlabel("Month as integers")
# Out:
# Text(0.5, 69.0, 'Month as integers')

# %% [markdown]
# # Scatter Plot

# %%
# bivariate analysis - scatter plot
i_data = pd.read_csv(r"C:\Users\lenovo\Documents\Uma\data\data fr viz\insurance.csv")

# %%
i_data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.scatterplot(x = i_data['age'], y = i_data['charges'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %%
sns.scatterplot(x = i_data['children'], y = i_data['charges'])
# Out:
# <AxesSubplot:xlabel='children', ylabel='charges'>

# %%
sns.scatterplot(x = i_data['age'], y = i_data['charges'], hue = i_data['smoker'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %%
sns.scatterplot(x = i_data['bmi'], y = i_data['charges'], hue = i_data['smoker'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.regplot(x = i_data['bmi'], y = i_data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.lmplot(x = 'bmi', y = 'charges', hue = 'smoker', data = i_data)

# %%
sns.swarmplot(x = i_data['smoker'], y = i_data['charges'])
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 67.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %%
sns.pairplot(i_data)

# %% [markdown]
# # Distribution plots

# %%
#univariate analysis - histogram
iris = pd.read_csv(r"C:\Users\lenovo\Documents\Uma\data\data fr viz\iris.csv", index_col = 'Id')

# %%
iris
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                  5.1               3.5                1.4               0.2
# 2                  4.9               3.0                1.4               0.2
# 3                  4.7               3.2                1.3               0.2
# 4                  4.6               3.1                1.5               0.2
# 5                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 146                6.7               3.0                5.2               2.3
# 147                6.3               2.5                5.0               1.9
# 148                6.5               3.0                5.2               2.0
# 149                6.2               3.4                5.4               2.3
# 150                5.9               3.0                5.1               1.8
#
#             Species
# Id
# ...

# %%
sns.distplot(a = iris['Petal Length (cm)'], kde = False)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Petal Length (cm)'>

# %%
sns.kdeplot(data = iris['Petal Length (cm)'], shade = True)
# Out:
# <AxesSubplot:xlabel='Petal Length (cm)', ylabel='Density'>

# %%
sns.jointplot(x = iris['Petal Length (cm)'], y= iris['Petal Width (cm)'], kind = 'kde')

# %% [markdown]
# #  Types of plots

# %% [markdown]
# ![seaborn.png](data:image/png;base64,...)

# %% [markdown]
# ![EKLyG1NW4AU6nno.jpeg](data:image/jpeg;base64,...)
